# %%
import pandas as pd
import numpy as np
import datetime
from os import listdir
from os.path import isfile, join
import glob
import re

# %%
df = pd.read_csv("country_vaccinations.csv")

# %%
df
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Argentina      ARG  2020-12-29               700.0              700.0
# 1     Argentina      ARG  2020-12-30                 NaN                NaN
# 2     Argentina      ARG  2020-12-31             32013.0            32013.0
# 3     Argentina      ARG  2021-01-01                 NaN                NaN
# 4     Argentina      ARG  2021-01-02                 NaN                NaN
# ...         ...      ...         ...                 ...                ...
# 1036      Wales      NaN  2021-01-13            113094.0           112973.0
# 1037      Wales      NaN  2021-01-14            126504.0           126375.0
# 1038      Wales      NaN  2021-01-15            126504.0           126375.0
# 1039      Wales      NaN  2021-01-16            126504.0           126375.0
# 1040      Wales      NaN  2021-01-17            151938.0           151737.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN             15656.0
# 2                         NaN                     NaN             15656.0
# 3                         NaN                     NaN             11070.0
# 4                         NaN                     NaN              8776.0
# ...                       ...                     ...                 ...
# 1036                    121.0                 11615.0              6828.0
# 1037                    129.0                 13410.0              8000.0
# 1038                    129.0                     0.0              7257.0
# 1039                    129.0                     0.0              6513.0
# 1040                    201.0                 25434.0              9403.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                           0.00
# 1                                NaN                            NaN
# 2                               0.07                           0.07
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 1036                            3.59                           3.58
# 1037                            4.01                           4.01
# 1038                            4.01                           4.01
# 1039                            4.01                           4.01
# 1040                            4.82                           4.81
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                           346.0
# 2                                     NaN                           346.0
# 3                                     NaN                           245.0
# 4                                     NaN                           194.0
# ...                                   ...                             ...
# 1036                                 0.00                          2166.0
# 1037                                 0.00                          2537.0
# 1038                                 0.00                          2302.0
# 1039                                 0.00                          2066.0
# 1040                                 0.01                          2982.0
#
#                                  vaccines                       source_name  \
# 0                               Sputnik V           Government of Argentina
# 1                               Sputnik V           Government of Argentina
# 2                               Sputnik V           Government of Argentina
# 3                               Sputnik V           Government of Argentina
# 4                               Sputnik V           Government of Argentina
# ...                                   ...                               ...
# 1036  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1037  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1038  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1039  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1040  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website
# 0     https://www.argentina.gob.ar/noticias/ya-se-ap...
# 1     https://www.argentina.gob.ar/noticias/ya-se-ap...
# 2     https://www.argentina.gob.ar/noticias/ya-se-ap...
# 3     https://www.argentina.gob.ar/noticias/ya-se-ap...
# 4     https://www.argentina.gob.ar/noticias/ya-se-ap...
# ...                                                 ...
# 1036  https://coronavirus.data.gov.uk/details/health...
# 1037  https://coronavirus.data.gov.uk/details/health...
# 1038  https://coronavirus.data.gov.uk/details/health...
# 1039  https://coronavirus.data.gov.uk/details/health...
# 1040  https://coronavirus.data.gov.uk/details/health...
#
# [1041 rows x 15 columns]

# %%
country_vaccine = data.groupby(["country", "iso_code", "vaccines"])['total_vaccinations', 
                                                                       'total_vaccinations_per_hundred',
                                                                      'daily_vaccinations',
                                                                      'daily_vaccinations_per_million',
                                                                      'people_vaccinated',
                                                                      'people_vaccinated_per_hundred'
                                                                      ].max().reset_index()
country_vaccine.columns = ["Country", "iso_code", "Vaccines", "Total vaccinations", "Percent", "Daily vaccinations", 
                           "Daily vaccinations per million", "People vaccinated", "People vaccinated per hundred"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-62bd52d42e95> in <module>
# ----> 1 country_vaccine = data.groupby(["country", "iso_code", "vaccines"])['total_vaccinations',
#       2                                                                        'total_vaccinations_per_hundred',
#       3                                                                       'daily_vaccinations',
#       4                                                                       'daily_vaccinations_per_million',
#       5                                                                       'people_vaccinated',
#
# NameError: name 'data' is not defined

# %%
country_vaccine
